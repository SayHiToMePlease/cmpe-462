# %%
import os
import polars as pl
import numpy as np
from IPython.display import display

# %%
df = pl.read_csv(os.path.join("data", "tabular", "feature_extraction.csv"))

y = df["class"]
X = df.drop("class")

X_np = X.to_numpy()
labels = y.to_list()

# %%
keep_indices = []
classes = sorted(set(labels))
for cls in classes:
    idx = [i for i, c in enumerate(labels) if c == cls]
    X_cls = X_np[idx]
    centroid = X_cls.mean(axis=0)
    distances = np.linalg.norm(X_cls - centroid, axis=1)
    n_keep = len(idx) // 2
    keep_local = np.argsort(distances)[:n_keep]
    keep_indices.extend([idx[i] for i in keep_local])

# %%
df_filtered = df[keep_indices]

output_path = os.path.join("data", "tabular", "feature_extraction_filtered.csv")
df_filtered.write_csv(output_path)
display(df_filtered)
# Out:
# shape: (2_500, 263)
# ┌────────────┬───────────┬────────────┬───────────┬───┬──────────┬──────────┬──────────┬────────┐
# │ blue_mean  ┆ blue_std  ┆ green_mean ┆ green_std ┆ … ┆ gray_253 ┆ gray_254 ┆ gray_255 ┆ class  │
# │ ---        ┆ ---       ┆ ---        ┆ ---       ┆   ┆ ---      ┆ ---      ┆ ---      ┆ ---    │
# │ f64        ┆ f64       ┆ f64        ┆ f64       ┆   ┆ f64      ┆ f64      ┆ f64      ┆ str    │
# ╞════════════╪═══════════╪════════════╪═══════════╪═══╪══════════╪══════════╪══════════╪════════╡
# │ 120.741783 ┆ 32.793851 ┆ 169.620102 ┆ 25.107267 ┆ … ┆ 168.0    ┆ 167.0    ┆ 167.0    ┆ banana │
# │ 82.309723  ┆ 26.191457 ┆ 173.781582 ┆ 20.617158 ┆ … ┆ 182.0    ┆ 181.0    ┆ 181.0    ┆ banana │
# │ 97.607487  ┆ 33.132291 ┆ 168.31699  ┆ 28.7028   ┆ … ┆ 205.0    ┆ 204.0    ┆ 202.0    ┆ banana │
# │ 99.971325  ┆ 39.213861 ┆ 174.068806 ┆ 29.406325 ┆ … ┆ 201.0    ┆ 200.0    ┆ 199.0    ┆ banana │
# │ 104.366985 ┆ 37.374431 ┆ 169.071167 ┆ 32.777409 ┆ … ┆ 184.0    ┆ 193.0    ┆ 197.0    ┆ banana │
# │ …          ┆ …         ┆ …          ┆ …         ┆ … ┆ …        ┆ …        ┆ …        ┆ …      │
# │ 163.688931 ┆ 99.905374 ┆ 175.510803 ┆ 87.761275 ┆ … ┆ 194.0    ┆ 198.0    ┆ 201.0    ┆ tomato │
# │ 168.310436 ┆ 86.073908 ┆ 173.151237 ┆ 78.543888 ┆ … ┆ 237.0    ┆ 236.0    ┆ 233.0    ┆ tomato │
# │ 190.739723 ┆ 75.640683 ┆ 197.101559 ┆ 64.302204 ┆ … ┆ 230.0    ┆ 234.0    ┆ 236.0    ┆ tomato │
# │ 162.301708 ┆ 86.245389 ┆ 169.485825 ┆ 76.904754 ┆ … ┆ 127.0    ┆ 150.0    ┆ 177.0    ┆ tomato │
# │ 181.959625 ┆ 87.498414 ┆ 191.832378 ┆ 77.7165   ┆ … ┆ 232.0    ┆ 236.0    ┆ 237.0    ┆ tomato │
# └────────────┴───────────┴────────────┴───────────┴───┴──────────┴──────────┴──────────┴────────┘
